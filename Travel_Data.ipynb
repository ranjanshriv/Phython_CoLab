# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjanshriv/Phython_CoLab/blob/main/Travel_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Read Travel File#

# %%
import pandas as pd
pd.options.display.float_format = '{:,.0f}'.format
#reading two sheets
df = pd.read_excel("/content/travel_data.xls",[0,1],3,usecols=['Country Code', '2016','2017'])
print(df[1])
#checking NaN value in column 2016 of 2nd sheet
df[1][~df[1]["2016"].isnull()]

#checking NaN value in all columns  of 2nd sheet  "~" using to reverse value result. e.g Isnull giving result True for NaN. ~using this it will False
df[1][~df[1].isnull().any(axis=1)]

#show all columns in dataframe
df[1].columns

#check datatype of all columns
df[1].dtypes

#select all columns with specific type
df[1].select_dtypes(include="float64")

# change index of Dataframe
df[1].index = df[1]["Country Code"]
df[1]
# Out:
# <ipython-input-61-a15f4a6db905>:4: FutureWarning: Starting with pandas version 2.0 all arguments of read_excel except for the arguments 'io' and 'sheet_name' will be keyword-only.
#   df = pd.read_excel("/content/travel_data.xls",[0,1],3,usecols=['Country Code', '2016','2017'])
#     Country Code      2016      2017
# 0            ABW       NaN       NaN
# 1            AFG       NaN       NaN
# 2            AGO       NaN       NaN
# 3            ALB 4,852,000 5,186,000
# 4            AND       NaN       NaN
# ..           ...       ...       ...
# 259          XKX       NaN       NaN
# 260          YEM       NaN       NaN
# 261          ZAF       NaN       NaN
# 262          ZMB       NaN       NaN
# 263          ZWE 3,192,000 2,768,000
#
# [264 rows x 3 columns]
#              Country Code      2016      2017
# Country Code
# ABW                   ABW       NaN       NaN
# AFG                   AFG       NaN       NaN
# AGO                   AGO       NaN       NaN
# ...

# %% [markdown]
# # New Section
